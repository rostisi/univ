# %%
print("Hello world")
# Out:
# Hello world

# %%
import numpy as np
from numpy import random

x=random.randint(100, size=(100)) # https://www.w3schools.com/python/numpy/numpy_random.asp
print(x)
# Out:
# [76 23 62 90 91 97 20 20  1 57 53 16 36 57 66 94 99 62 98 97 12 78 99 54
#   3 60  1 22 72 76 32 94 28 74 64 28 65 45 18 66 34  5 87 24 12 94 77 18
#  44 66  7 55 86 60 24 80 43 96 83 37 61 10 75 44 97 86 15 75  7 36 49 94
#   0 32 28 98 47 78 64 13 83 91 32 82 95 93 53  2 58 70 55 66 74 54 96 13
#  40 15 99 89]

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import random

x=random.randint(100, size=(100)) 
print(x)
plt.plot(x) # https://www.w3schools.com/python/matplotlib_plotting.asp
plt.show()
# Out:
# [29 99 83 95 71 97 93 25  7 91 23 99 56 62 48  0 91 77 77 50 85 19 19  5
#  53  5 66 21  1 66  7 38 33 62 43 68 52 37  8 89 93  8 50 98 64 49  7 24
#  28 78  8 86 25 88 11 80 85 48 77 70 45 98 98 62 67 95 20 40 87 22 16 78
#  37 12 99 28 65 86 13 88 68 83 22 82 62  9 75 84 35  7 39  0 55 31 65 71
#  48 60  2 51]

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

df = pd.read_csv(url)

columns = ["Times Pregnant", "Plasma Glucose", "Diastolic Blood Pressure", 
                "Skin Thickness", "Serum Insulin", "Body mass",
                "Diabetes Pedigree", "Age", "Class Variable"]

info = pd.read_csv(url, names=columns)

print(info.shape)
print(info.isnull().sum()) # https://medium.com/analytics-vidhya/python-finding-missing-values-in-a-data-frame-3030aaf0e4fd
# Out:
# (768, 9)
# Times Pregnant              0
# Plasma Glucose              0
# Diastolic Blood Pressure    0
# Skin Thickness              0
# Serum Insulin               0
# Body mass                   0
# Diabetes Pedigree           0
# Age                         0
# Class Variable              0
# dtype: int64

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

df = pd.read_csv(url)

columns = ["Times Pregnant", "Plasma Glucose", "Diastolic Blood Pressure", 
                "Skin Thickness", "Serum Insulin", "Body mass",
                "Diabetes Pedigree", "Age", "Class Variable"]

info = pd.read_csv(url, names=columns)

#print(info.columns)

#pregnant = info["Times Pregnant"] # https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html
#print(np.where(pregnant<=-1)) # https://stackoverflow.com/questions/13869173/numpy-find-index-of-the-elements-within-range
#glucose = info["Plasma Glucose"]
#print(np.where(glucose<=0))

missing_data = (info[columns] == 0).sum()

print(missing_data)
# Out:
# Times Pregnant              111
# Plasma Glucose                5
# Diastolic Blood Pressure     35
# Skin Thickness              227
# Serum Insulin               374
# Body mass                    11
# Diabetes Pedigree             0
# Age                           0
# Class Variable              500
# dtype: int64

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

df = pd.read_csv(url)

columns = ["Times Pregnant", "Plasma Glucose", "Diastolic Blood Pressure", 
                "Skin Thickness", "Serum Insulin", "Body mass",
                "Diabetes Pedigree", "Age", "Class Variable"]

info = pd.read_csv(url, names=columns)

# num_of_rows = len(info)

# sum = (info[columns]).sum()
# avg_sum = sum/num_of_rows

print("Average:", "\n", info.mean(), "\n") #https://www.geeksforgeeks.org/create-the-mean-and-standard-deviation-of-the-data-of-a-pandas-series/
print("Variance:", "\n", info.var(), "\n") #https://www.w3schools.com/python/pandas/ref_df_std.asp#:~:text=The%20var()%20method%20calculates,the%20variance%20for%20each%20row.
print("Standart Deviation", "\n", info.std()) #https://www.geeksforgeeks.org/create-the-mean-and-standard-deviation-of-the-data-of-a-pandas-series/
# Out:
# Average:
#  Times Pregnant                3.845052
# Plasma Glucose              120.894531
# Diastolic Blood Pressure     69.105469
# Skin Thickness               20.536458
# Serum Insulin                79.799479
# Body mass                    31.992578
# Diabetes Pedigree             0.471876
# Age                          33.240885
# Class Variable                0.348958
# dtype: float64
#
# Variance:
#  Times Pregnant                 11.354056
# Plasma Glucose               1022.248314
# Diastolic Blood Pressure      374.647271
# Skin Thickness                254.473245
# Serum Insulin               13281.180078
# Body mass                      62.159984
# Diabetes Pedigree               0.109779
# Age                           138.303046
# Class Variable                  0.227483
# dtype: float64
#
# Standart Deviation
#  Times Pregnant                3.369578
# Plasma Glucose               31.972618
# Diastolic Blood Pressure     19.355807
# Skin Thickness               15.952218
# Serum Insulin               115.244002
# Body mass                     7.884160
# Diabetes Pedigree             0.331329
# Age                          11.760232
# Class Variable                0.476951
# dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import colors
from matplotlib.ticker import PercentFormatter

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

df = pd.read_csv(url)

columns = ["Times Pregnant", "Plasma Glucose", "Diastolic Blood Pressure", 
                "Skin Thickness", "Serum Insulin", "Body mass",
                "Diabetes Pedigree", "Age", "Class Variable"]

info = pd.read_csv(url, names=columns)

plt.hist(info["Times Pregnant"])
plt.xlabel("Times Pregnant")
plt.ylabel("Frequency")
plt.title("Times Pregnant")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import colors
from matplotlib.ticker import PercentFormatter

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

df = pd.read_csv(url)

columns = ["Times Pregnant", "Plasma Glucose", "Diastolic Blood Pressure", 
                "Skin Thickness", "Serum Insulin", "Body mass",
                "Diabetes Pedigree", "Age", "Class Variable"]

info = pd.read_csv(url, names=columns)

plt.hist(info["Plasma Glucose"])
plt.xlabel("Plasma Glucose")
plt.ylabel("Frequency")
plt.title("Plasma Glucose")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import colors
from matplotlib.ticker import PercentFormatter

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

df = pd.read_csv(url)

columns = ["Times Pregnant", "Plasma Glucose", "Diastolic Blood Pressure", 
                "Skin Thickness", "Serum Insulin", "Body mass",
                "Diabetes Pedigree", "Age", "Class Variable"]

info = pd.read_csv(url, names=columns)

plt.hist(info["Diastolic Blood Pressure"])
plt.xlabel("Blood Pressure")
plt.ylabel("Frequency")
plt.title("Blood Pressure")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import colors
from matplotlib.ticker import PercentFormatter

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

df = pd.read_csv(url)

columns = ["Times Pregnant", "Plasma Glucose", "Diastolic Blood Pressure", 
                "Skin Thickness", "Serum Insulin", "Body mass",
                "Diabetes Pedigree", "Age", "Class Variable"]

info = pd.read_csv(url, names=columns)

plt.hist(info["Skin Thickness"])
plt.xlabel("Skin Thickness")
plt.ylabel("Frequency")
plt.title("Skin Thickness")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import colors
from matplotlib.ticker import PercentFormatter

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

df = pd.read_csv(url)

columns = ["Times Pregnant", "Plasma Glucose", "Diastolic Blood Pressure", 
                "Skin Thickness", "Serum Insulin", "Body mass",
                "Diabetes Pedigree", "Age", "Class Variable"]

info = pd.read_csv(url, names=columns)

plt.hist(info["Serum Insulin"])
plt.xlabel("Serum Insulin")
plt.ylabel("Frequency")
plt.title("Serum Insulin")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import colors
from matplotlib.ticker import PercentFormatter

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

df = pd.read_csv(url)

columns = ["Times Pregnant", "Plasma Glucose", "Diastolic Blood Pressure", 
                "Skin Thickness", "Serum Insulin", "Body mass",
                "Diabetes Pedigree", "Age", "Class Variable"]

info = pd.read_csv(url, names=columns)

plt.hist(info["Body mass"])
plt.xlabel("Body mass")
plt.ylabel("Frequency")
plt.title("Body mass")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import colors
from matplotlib.ticker import PercentFormatter

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

df = pd.read_csv(url)

columns = ["Times Pregnant", "Plasma Glucose", "Diastolic Blood Pressure", 
                "Skin Thickness", "Serum Insulin", "Body mass",
                "Diabetes Pedigree", "Age", "Class Variable"]

info = pd.read_csv(url, names=columns)

plt.hist(info["Diabetes Pedigree"])
plt.xlabel("Diabetes Pedigree")
plt.ylabel("Frequency")
plt.title("Diabetes Pedigree")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import colors
from matplotlib.ticker import PercentFormatter

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

df = pd.read_csv(url)

columns = ["Times Pregnant", "Plasma Glucose", "Diastolic Blood Pressure", 
                "Skin Thickness", "Serum Insulin", "Body mass",
                "Diabetes Pedigree", "Age", "Class Variable"]

info = pd.read_csv(url, names=columns)

plt.hist(info["Age"])
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Age")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import colors
from matplotlib.ticker import PercentFormatter

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

df = pd.read_csv(url)

columns = ["Times Pregnant", "Plasma Glucose", "Diastolic Blood Pressure", 
                "Skin Thickness", "Serum Insulin", "Body mass",
                "Diabetes Pedigree", "Age", "Class Variable"]

info = pd.read_csv(url, names=columns)

plt.hist(info["Class Variable"])
plt.xlabel("Class Variable")
plt.ylabel("Frequency")
plt.title("Class Variable")
plt.show()
